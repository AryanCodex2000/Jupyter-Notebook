# %%
! pip install transformers
# Out:
# ...
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.5 MB 1.4 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/10.5 MB 1.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/10.5 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.5 MB 1.6 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/10.5 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/10.5 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/10.5 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/10.5 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.1/10.5 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.7/10.5 MB 1.6 MB/s eta 0:00:05
# ...

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Aryan is a good and intelligent boy"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['aryan', 'is', 'a', 'good', 'and', 'intelligent', 'boy']
