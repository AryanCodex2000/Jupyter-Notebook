# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 2.5 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.8/12.8 MB 2.7 MB/s eta 0:00:05
#      -------- ------------------------------- 2.6/12.8 MB 3.0 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.8 MB 3.2 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 3.2 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.5/12.8 MB 3.3 MB/s eta 0:00:03
#      ------------------- -------------------- 6.3/12.8 MB 3.3 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.8 MB 3.4 MB/s eta 0:00:02
# ...

# %%
import spacy 

nlp = spacy.load("en_core_web_sm")
text = "Apple Inc. is looking to buy a U.K. startup for $1 billion."

doc = nlp(text)

for token in doc:
    print(token.text)
# Out:
# Apple
# Inc.
# is
# looking
# to
# buy
# a
# U.K.
# startup
# for
# $
# 1
# billion
# .
