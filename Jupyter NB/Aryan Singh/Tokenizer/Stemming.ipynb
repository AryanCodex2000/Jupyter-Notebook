# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

stemmer = PorterStemmer()
words = ["running", "happiness", "files", "dies", "fairly", "madnees", "lazyness", "Effectiveness", "bees", "cars"]

for word in words:
    print(f"{word} -> {stemmer.stem(word)}")
# Out:
# running -> run
# happiness -> happi
# files -> file
# dies -> die
# fairly -> fairli
# madnees -> madne
# lazyness -> lazy
# Effectiveness -> effect
# bees -> bee
# cars -> car
