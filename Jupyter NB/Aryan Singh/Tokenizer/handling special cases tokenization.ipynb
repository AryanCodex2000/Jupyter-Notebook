# %%
! pip install spacy
! pip install nltk
! pip install nlp
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 932.9 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 932.9 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.7 MB 932.9 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 633.2 kB/s eta 0:00:02
#    ------------------ --------------------- 0.8/1.7 MB 633.2 kB/s eta 0:00:02
#    ------------------------- -------------- 1.0/1.7 MB 585.1 kB/s eta 0:00:02
#    ------------------------- -------------- 1.0/1.7 MB 585.1 kB/s eta 0:00:02
#    ------------------------- -------------- 1.0/1.7 MB 585.1 kB/s eta 0:00:02
# ...

# %%
tweet = "Hey @NLP_fans! #Tokenization is 🔥. Check out https://example.com"
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(tweet)
print([token.text for token in doc])
# Out:
# ['Hey', '@NLP_fans', '!', '#', 'Tokenization', 'is', '🔥', '.', 'Check', 'out', 'https://example.com']

# %%
tweet = "Hey @NLP_fans! #Tokenization is 🔥. Check out https://example.com"
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(tweet)
print([token.text for token in doc])
# Out:
# ['Hey', '@NLP_fans', '!', '#', 'Tokenization', 'is', '🔥', '.', 'Check', 'out', 'https://example.com']

# %%
tweet = "Hey @NLP_fans! #Tokenization is 🔥. Check out https://example.com"
import spacy
nlp = spacy.load("en_core_web_sm")
doc = nlp(tweet)
print([token.text for token in doc])
# Out:
# ['Hey', '@NLP_fans', '!', '#', 'Tokenization', 'is', '🔥', '.', 'Check', 'out', 'https://example.com']

# %%
tweet = "Hey @NLP_fans! #Tokenization is 🔥. Check out https://example.com"
import spacy 
nlp = spacy.load("en_core_web_sm")
doc = nlp(tweet)
print([token.text for token in doc])
# Out:
# ['Hey', '@NLP_fans', '!', '#', 'Tokenization', 'is', '🔥', '.', 'Check', 'out', 'https://example.com']
