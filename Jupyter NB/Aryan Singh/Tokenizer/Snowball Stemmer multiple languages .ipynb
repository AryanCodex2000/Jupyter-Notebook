# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")
print(stemmer.stem("running"))

stemmer_spanish = SnowballStemmer("spanish")
print(stemmer_spanish.stem("corriendo"))
# Out:
# run
# corr

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")
print(stemmer.stem("running"))

stemmer_spanish = SnowballStemmer("spanish")
print(stemmer_spanish.stem("corriendo"))
# Out:
# run
# corr

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")
print(stemmer.stem("running"))

stemmer_spanish = SnowballStemmer("spanish")
print(stemmer_spanish.stem("corriendo"))
# Out:
# run
# corr

# %%
from nltk.stem import SnowballStemmer

stemmer = SnowballStemmer("english")
print(stemmer.stem("running"))

stemmer_spanish = SnowballStemmer("spanish")
print(stemmer_spanish.stem("corriendo"))
# Out:
# run
# corr
