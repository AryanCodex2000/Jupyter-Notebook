# %%
! pip install transformers

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello Aryan how's the tokenizer project is going on!"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'aryan', 'how', "'", 's', 'the', 'token', '##izer', 'project', 'is', 'going', 'on', '!']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello Aryan Singh"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'aryan', 'singh']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello everyone this is me Aryan Singh"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'everyone', 'this', 'is', 'me', 'aryan', 'singh']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello everyone is all going good"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'everyone', 'is', 'all', 'going', 'good']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello Iron Man you are rrally awesome"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'iron', 'man', 'you', 'are', 'rr', '##ally', 'awesome']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello everyone today is thursday"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'everyone', 'today', 'is', 'thursday']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello everyone i am aryan singh"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'everyone', 'i', 'am', 'aryan', 'singh']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello Aryan how is it going now are u learning the transformers in tokenizers or not "
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'aryan', 'how', 'is', 'it', 'going', 'now', 'are', 'u', 'learning', 'the', 'transformers', 'in', 'token', '##izer', '##s', 'or', 'not']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hi everyone is everything working perfectly all right or not"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hi', 'everyone', 'is', 'everything', 'working', 'perfectly', 'all', 'right', 'or', 'not']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello Smarty u are really crazy"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'smart', '##y', 'u', 'are', 'really', 'crazy']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Are you there or not sir"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['are', 'you', 'there', 'or', 'not', 'sir']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Hello everyone"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['hello', 'everyone']

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "No i am all right sir"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['no', 'i', 'am', 'all', 'right', 'sir']
