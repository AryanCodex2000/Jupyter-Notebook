# %%
vocab = ["cat","dog","bird","fish"]
word_to_index = {word: i for i, word in enumerate(vocab)}
print("Word to index mapping:", word_to_index)

def one_hot_encode(word, word_to_index):
    vector = [0] * len(word_to_index)
    index = word_to_index[word]
    vector[index] = 1
    return vector

print("One-hot for 'dog':", one_hot_encode("dog", word_to_index))
# Out:
# Word to index mapping: {'cat': 0, 'dog': 1, 'bird': 2, 'fish': 3}
# '\ndef one_hot_encode(word, word_to_index):\n    vector = [0] * len(word_to_index)\n    index = word_to_index[word]\n    vector[index] = 1\n    return vector\n\nprint("One-hot for \'dog\':", one_hot_encode("dog", word_to_index))'

# %%
web = ["cat","dog","bird","fish"]
words = {word: i for i, word in enumerate(web)}
print("Word to index mappinig: ", words)

def one_hot_encode(word, words):
    vector = [0] * len(words)
    index = words[word]
    vector[index] = 1
    return vector
print("One hot for 'dog':", one_hot_encode("dog", words))
# Out:
# Word to index mappinig:  {'cat': 0, 'dog': 1, 'bird': 2, 'fish': 3}
# One hot for 'dog': [0, 1, 0, 0]

# %%
vocab = ["boy","girl","animal","mammal"]
words = {word: i for i, word in enumerate(vocab)}
print("Word to index mapping: ", words)

def one_hot_encode(word, words):
    vector = [0] * len(words)
    index = words[word]
    vector[index] = 3453453453
    return vector
print("One hot encoder is workoing and this is the output 'animal'", one_hot_encode("animal", words))
print("One hot encoder is workoing and this is the output 'girl': ", one_hot_encode("girl", words))
print("One hot encoder is workoing and this is the output 'boy': ", one_hot_encode("boy", words))
print("One hot encoder is workoing and this is the output 'mammal': ", one_hot_encode("mammal", words))
# Out:
# Word to index mapping:  {'boy': 0, 'girl': 1, 'animal': 2, 'mammal': 3}
# One hot encoder is workoing and this is the output 'animal' [0, 0, 3453453453, 0]
# One hot encoder is workoing and this is the output 'girl':  [0, 3453453453, 0, 0]
# One hot encoder is workoing and this is the output 'boy':  [3453453453, 0, 0, 0]
# One hot encoder is workoing and this is the output 'mammal':  [0, 0, 0, 3453453453]

# %%
vocab = ["one","two","three","four","five","six"]
words = {word: i for i, word in enumerate(vocab)}
print("Printiing all in the number format we get: ", words)

def one_hot_encode(word, words):
    vector = [0] * len(words)
    index = words[word]
    vector[index] = 1
    return vector
print("this is the required out put for 'four': ", one_hot_encode("four", words) )
print(" this is the required output for 'one': ", one_hot_encode("one", words))
print(" this is the required output for 'two': ", one_hot_encode("two", words))
print(" this is the required output for 'three': ", one_hot_encode("three", words))
print(" this is the required output for 'five': ", one_hot_encode("five", words))
print(" this is the required output for 'six': ", one_hot_encode("six", words))
# Out:
# Printiing all in the number format we get:  {'one': 0, 'two': 1, 'three': 2, 'four': 3, 'five': 4, 'six': 5}
# this is the required out put for 'four':  [0, 0, 0, 1, 0, 0]
#  this is the required output for 'one':  [1, 0, 0, 0, 0, 0]
#  this is the required output for 'two':  [0, 1, 0, 0, 0, 0]
#  this is the required output for 'three':  [0, 0, 1, 0, 0, 0]
#  this is the required output for 'five':  [0, 0, 0, 0, 1, 0]
#  this is the required output for 'six':  [0, 0, 0, 0, 0, 1]
