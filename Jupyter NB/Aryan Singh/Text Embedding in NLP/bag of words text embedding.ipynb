# %%
from sklearn.feature_extraction.text import CountVectorizer

# Sample sentences
sentences = [
    "the cat sat on the mat",
    "the dog ate the cat's food"
]

# Create BoW model
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(sentences)

# Vocabulary
print("Vocabulary:", vectorizer.get_feature_names_out())
# Output: ['ate', 'cat', 'dog', 'food', 'mat', 'on', 'sat', 'the']

# BoW vectors
print("BoW Matrix:\n", X.toarray())
# Out:
# Vocabulary: ['ate' 'cat' 'dog' 'food' 'mat' 'on' 'sat' 'the']
# BoW Matrix:
#  [[0 1 0 0 1 1 1 2]
#  [1 1 1 1 0 0 0 2]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
sentences = [
    "the cat sat on the mat",
    "the dog ate the cat's food"
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(sentences)
print("Vocabulary:", vectorizer.get_feature_names_out())
print("BOW Matrix:\n", X.toarray())
# Out:
# Vocabulary: ['ate' 'cat' 'dog' 'food' 'mat' 'on' 'sat' 'the']
# BOW Matrix:
#  [[0 1 0 0 1 1 1 2]
#  [1 1 1 1 0 0 0 2]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
sentences = [
    "the cat sat on the mat",
    "the dog ate the cat's food"
]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(sentences)
print("Vocabulary:", vectorizer.get_feature_names_out())
print("BOW Matrix:\n", X.toarray())
# Out:
# Vocabulary: ['ate' 'cat' 'dog' 'food' 'mat' 'on' 'sat' 'the']
# BOW Matrix:
#  [[0 1 0 0 1 1 1 2]
#  [1 1 1 1 0 0 0 2]]

# %%
from sklearn.feature_extraction.text import CountVectorizer
sentences = [
    "the cat sat on the mat",
    "the dog ate the cat's food"
]
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(sentences)
print("Vocabulary:", vectorizer.get_feature_names_out())
print("BOW:\n", X.toarray())
# Out:
# Vocabulary: ['ate' 'cat' 'dog' 'food' 'mat' 'on' 'sat' 'the']
# BOW:
#  [[0 1 0 0 1 1 1 2]
#  [1 1 1 1 0 0 0 2]]
