# %%
println("Hello My dear little frnd ")
# Out:
# Hello My dear little frnd

# %%
my_age = 5+5 
println("I am $my_age years old!")
# Out:
# I am 10 years old!

# %%
animals = ["🐶", "🐱", "🐭", "🦄"]
println("My favourite animal is $(animals[1])!")
# Out:
# My favourite animal is 🐶!

# %%
import Pkg
Pkg.add("DataFrames")

#Pkg.add(["CSV", "Plots", "Statistics", "Chain", "Dates"])

using DataFrames

candy_jar = DataFrame(
    color = ["red", "green", "blue", "red", "yellow"],
    type = ["lollipop", "gum", "chocolate", "gum", "chocolate"],
    count = [5, 3, 10, 2, 7]
)

println("Look at all our candy!")
println(candy_jar)
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\HP\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\HP\.julia\environments\v1.11\Manifest.toml`
# Look at all our candy!
# 5×3 DataFrame
#  Row │ color   type       count
#      │ String  String     Int64
# ─────┼──────────────────────────
#    1 │ red     lollipop       5
#    2 │ green   gum            3
#    3 │ blue    chocolate     10
#    4 │ red     gum            2
#    5 │ yellow  chocolate      7

# %%
import Pkg
Pkg.add("DataFrames")

#Pkg.add(["CSV", "Plots", "Statistics", "Chain", "Dates"])

using DataFrames

candy_jar = DataFrame(
    color = ["red", "green", "blue", "red", "yellow"],
    type = ["lollipop", "gum", "chocolate", "gum", "chocolate"],
    count = [5, 3, 10, 2, 7]
)

println("Look at all our candy!")
println(candy_jar)
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\HP\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\HP\.julia\environments\v1.11\Manifest.toml`
# Look at all our candy!
# 5×3 DataFrame
#  Row │ color   type       count
#      │ String  String     Int64
# ─────┼──────────────────────────
#    1 │ red     lollipop       5
#    2 │ green   gum            3
#    3 │ blue    chocolate     10
#    4 │ red     gum            2
#    5 │ yellow  chocolate      7
